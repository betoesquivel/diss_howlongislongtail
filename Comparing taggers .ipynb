# %%
import sample_data
from linkers_and_taggers import tagme_tag, stanford_tag, stanford_tagger, wikifier_tag
import pprint
pp = pprint.PrettyPrinter()
tagger = stanford_tagger()

# %%
docs = sample_data.n_samples(50)

# %% [markdown]
# ## Documents that don't fail
#     0 with length of 2335
#     1 with length of 3740
#     3 with length of 9513
#     23 with length of 12169
#
# ## Documents that fail
#     31 with length of 16054 (same as 48) but sometimes
#     36 with length of 12418
#     48 with length of 12830 (tagme raises status code error, wikifier returns empty list)

# %%
doc = docs[36]
print "Document has length of: {0}".format(len(doc['content']))
doc['content']
[(i, len(doc['content'])) for doc in docs if len(doc['content'])> 12000]
# Out:
# Document has length of: 12418
# [(49, 12169), (49, 16054), (49, 12418), (49, 12830)]

# %%
tagme_tags = tagme_tag(doc['content'])
tagme_tags
# Out:
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-115-98b428965fbe> in <module>()
# ----> 1 tagme_tags = tagme_tag(doc['content'])
#       2 tagme_tags
#
# /Users/betoesquivel/workspace/dissertation/how_long_is_long_tail/linkers_and_taggers.pyc in <lambda>(text)
#      30 }
#      31 tagme_call = lambda text: requests.get(TAGME_URL, params=tagme_payload(text))
# ---> 32 tagme_tag = lambda text: json_foolproof_loads(tagme_call(text).text).get('annotations', [])
#      33
#      34 # WIKIFIER
#
# /Users/betoesquivel/workspace/dissertation/how_long_is_long_tail/linkers_and_taggers.pyc in <lambda>(text)
#      29     'gcube-token': TAGME_KEY
#      30 }
# ---> 31 tagme_call = lambda text: requests.get(TAGME_URL, params=tagme_payload(text))
#      32 tagme_tag = lambda text: json_foolproof_loads(tagme_call(text).text).get('annotations', [])
#      33
#
# /Users/betoesquivel/Envs/diss/lib/python2.7/site-packages/requests/api.pyc in get(url, params, **kwargs)
#      69
#      70     kwargs.setdefault('allow_redirects', True)
# ---> 71     return request('get', url, params=params, **kwargs)
#      72
#      73
#
# /Users/betoesquivel/Envs/diss/lib/python2.7/site-packages/requests/api.pyc in request(method, url, **kwargs)
#      55     # cases, and look like a memory leak in others.
#      56     with sessions.Session() as session:
# ---> 57         return session.request(method=method, url=url, **kwargs)
#      58
#      59
#
# /Users/betoesquivel/Envs/diss/lib/python2.7/site-packages/requests/sessions.pyc in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     473         }
#     474         send_kwargs.update(settings)
# --> 475         resp = self.send(prep, **send_kwargs)
#     476
#     477         return resp
#
# /Users/betoesquivel/Envs/diss/lib/python2.7/site-packages/requests/sessions.pyc in send(self, request, **kwargs)
#     583
#     584         # Send the request
# --> 585         r = adapter.send(request, **kwargs)
#     586
#     587         # Total elapsed time of the request (approximately)
#
# /Users/betoesquivel/Envs/diss/lib/python2.7/site-packages/requests/adapters.pyc in send(self, request, stream, timeout, verify, cert, proxies)
#     451
#     452         except (ProtocolError, socket.error) as err:
# --> 453             raise ConnectionError(err, request=request)
#     454
#     455         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', BadStatusLine('<html>\r\n',))

# %%
wikifier_tags = wikifier_tag(doc['content'])
wikifier_tags
# Out:
# []

# %%
stanford_tags = stanford_tag(doc['content'], tagger)
stanford_tags
# Out:
# [(u'Virgin', u'O'),
#  (u'America,', u'O'),
#  (u'the', u'O'),
#  (u'low-fare,', u'O'),
#  (u'upscale', u'O'),
#  (u'airline', u'O'),
#  (u'today', u'O'),
#  (u'teams', u'O'),
#  (u'up', u'O'),
#  (u'with', u'O'),
#  (u'Uber', u'O'),
#  (u'to', u'O'),
#  (u'launch', u'O'),
#  (u'some', u'O'),
#  (u'Texas-sized', u'O'),
#  (u'deals', u'O'),
#  (u'for', u'O'),
#  (u'Dallas', u'LOCATION'),
#  (u'flyers', u'O'),
#  (u'-', u'O'),
#  (u'including', u'O'),
#  (u'a', u'O'),
#  (u'free', u'O'),
#  (u'Uber', u'O'),
#  (u'ride', u'O'),
#  (u'(up', u'O'),
#  (u'to', u'O'),
#  (u'$20)*', u'O'),
#  (u'with', u'O'),
#  (u'the', u'O'),
#  (u'purchase', u'O'),
#  (u'of', u'O'),
#  (u'any', u'O'),
#  (u'flight', u'O'),
#  (u'departing', u'O'),
#  (u'from', u'O'),
#  (u'Dallas', u'LOCATION'),
#  (u'Love', u'O'),
#  (u'Field', u'O'),
#  (u'(DAL)', u'O'),
#  (u'and', u'O'),
#  (u'a', u'O'),
#  (u"'Friday", u'O'),
#  (u'Night', u'O'),
#  (u"Flights'", u'O'),
#  (u'series', u'O'),
#  (u'that', u'O'),
#  (u'allows', u'O'),
#  (u'local', u'O'),
#  (u'travelers', u'O'),
#  (u'to', u'O'),
#  (u'score', u'O'),
#  (u'the', u'O'),
#  (u'ultimate,', u'O'),
#  (u'on-demand', u'O'),
#  (u'weekend', u'O'),
#  (u'getaway', u'O'),
#  (u'through', u'O'),
#  (u'the', u'O'),
#  (u'Uber', u'O'),
#  (u'app**', u'O'),
#  (u'in', u'O'),
#  (u'partnership', u'O'),
#  (u'with', u'O'),
#  (u'Rocketmiles', u'LOCATION'),
#  (u'and', u'O'),
#  (u'ScoreBig(TM).', u'LOCATION'),
#  (u'Virgin', u'LOCATION'),
#  (u'America', u'LOCATION'),
#  (u'is', u'O'),
#  (u'also', u'O'),
#  (u'launching', u'O'),
#  (u'a', u'O'),
#  (u'Dallas', u'LOCATION'),
#  (u'Love', u'LOCATION'),
#  (u'Field', u'LOCATION'),
#  (u'fare', u'O'),
#  (u'sale', u'O'),
#  (u'this', u'O'),
#  (u'week,', u'O'),
#  (u'with', u'O'),
#  (u'tickets', u'O'),
#  (u'to', u'O'),
#  (u'Austin', u'LOCATION'),
#  (u'starting', u'O'),
#  (u'from', u'O'),
#  (u'$67', u'O'),
#  (u'and', u'O'),
#  (u'tickets', u'O'),
#  (u'to', u'O'),
#  (u'Los', u'LOCATION'),
#  (u'Angeles', u'LOCATION'),
#  (u'starting', u'O'),
#  (u'from', u'O'),
#  (u'$99', u'O'),
#  (u'(must', u'O'),
#  (u'be', u'O'),
#  (u'purchased', u'O'),
#  (u'by', u'O'),
#  (u'11.59pm', u'O'),
#  (u'PT,', u'O'),
#  (u'September', u'O'),
#  (u'10,', u'O'),
#  (u'2015,', u'O'),
#  (u'restrictions', u'O'),
#  (u'apply)***.', u'O'),
#  (u'Travelers', u'O'),
#  (u'can', u'O'),
#  (u'grab', u'O'),
#  (u'these', u'O'),
#  (u'fares', u'O'),
#  (u'and', u'O'),
#  (u'a', u'O'),
#  (u'ride', u'O'),
#  (u'at', u'O'),
#  (u'virginamerica.com', u'O'),
#  (u'or', u'O'),
#  (u'by', u'O'),
#  (u'calling', u'O'),
#  (u'1.877.FLY.VIRGIN', u'O'),
#  (u'(1.877.359.8474)', u'O'),
#  (u'****.', u'O'),
#  (u'"With', u'O'),
#  (u'our', u'O'),
#  (u'stylish,', u'O'),
#  (u'low-fare', u'O'),
#  (u'flights', u'O'),
#  (u'departing', u'O'),
#  (u'daily', u'O'),
#  (u'from', u'O'),
#  (u'downtown', u'O'),
#  (u'Dallas', u'LOCATION'),
#  (u'to', u'O'),
#  (u'New', u'O'),
#  (u'York,', u'O'),
#  (u'Washington', u'LOCATION'),
#  (u'D.C.,', u'O'),
#  (u'Los', u'O'),
#  (u'Angeles,', u'O'),
#  (u'San', u'O'),
#  (u'Francisco,', u'O'),
#  (u'and', u'O'),
#  (u'Austin,', u'O'),
#  (u"we're", u'O'),
#  (u'excited', u'O'),
#  (u'to', u'O'),
#  (u'offer', u'O'),
#  (u'even', u'O'),
#  (u'more', u'O'),
#  (u'perks', u'O'),
#  (u'and', u'O'),
#  (u'great', u'O'),
#  (u'deals', u'O'),
#  (u'to', u'O'),
#  (u'Dallas', u'LOCATION'),
#  (u'flyers,"', u'O'),
#  (u'said', u'O'),
#  (u'Luanne', u'PERSON'),
#  (u'Calvert,', u'O'),
#  (u'Chief', u'O'),
#  (u'Marketing', u'O'),
#  (u'Officer', u'O'),
#  (u'at', u'O'),
#  (u'Virgin', u'LOCATION'),
#  (u'America.', u'LOCATION'),
#  (u'"We\'re', u'O'),
#  (u'looking', u'O'),
#  (u'forward', u'O'),
#  (u'to', u'O'),
#  (u'kicking', u'O'),
#  (u'off', u'O'),
#  (u"'Friday", u'O'),
#  (u'Night', u'O'),
#  (u"Flights'", u'O'),
#  (u'with', u'O'),
#  (u'a', u'O'),
#  (u'series', u'O'),
#  (u'of', u'O'),
#  (u'on-demand', u'O'),
#  (u'music-packed', u'O'),
#  (u'weekend', u'O'),
#  (u'getaways.', u'O'),
#  (u'And', u'O'),
#  (u'because', u'O'),
#  (u'we', u'O'),
#  (u'know', u'O'),
#  (u'time', u'O'),
#  (u'is', u'O'),
#  (u'of', u'O'),
#  (u'the', u'O'),
#  (u'essence,', u'O'),
#  (u'particularly', u'O'),
#  (u'for', u'O'),
#  (u'our', u'O'),
#  (u'business', u'O'),
#  (u'travelers', u'O'),
#  (u'looking', u'O'),
#  (u'to', u'O'),
#  (u'skip', u'O'),
#  (u'the', u'O'),
#  (u'parking', u'O'),
#  (u'lot,', u'O'),
#  (u"we're", u'O'),
#  (u'partnering', u'O'),
#  (u'with', u'O'),
#  (u'Uber', u'O'),
#  (u'to', u'O'),
#  (u'make', u'O'),
#  (u'getting', u'O'),
#  (u'to', u'O'),
#  (u'the', u'O'),
#  (u'airport', u'O'),
#  (u'located', u'O'),
#  (u'closest', u'O'),
#  (u'to', u'O'),
#  (u'downtown', u'O'),
#  (u'even', u'O'),
#  (u'more', u'O'),
#  (u'convenient', u'O'),
#  (u'and', u'O'),
#  (u'rewarding', u'O'),
#  (u'for', u'O'),
#  (u'our', u'O'),
#  (u'Elevate', u'O'),
#  (u'members."', u'O'),
#  (u'More', u'O'),
#  (u'about', u'O'),
#  (u'the', u'O'),
#  (u'promotions:', u'O'),
#  (u'Free', u'O'),
#  (u'Rides', u'O'),
#  (u'to', u'O'),
#  (u'Dallas', u'LOCATION'),
#  (u'Love', u'O'),
#  (u'Field:', u'O'),
#  (u'With', u'O'),
#  (u'its', u'O'),
#  (u'modern,', u'O'),
#  (u'convenient', u'O'),
#  (u'location,', u'O'),
#  (u'Dallas', u'LOCATION'),
#  (u'Love', u'LOCATION'),
#  (u'Field', u'LOCATION'),
#  (u'has', u'O'),
#  (u'become', u'O'),
#  (u'an', u'O'),
#  (u'increasingly', u'O'),
#  (u'popular', u'O'),
#  (u'airport', u'O'),
#  (u'for', u'O'),
#  (u'local', u'O'),
#  (u'travelers', u'O'),
#  (u'-', u'O'),
#  (u'and', u'O'),
#  (u'Virgin', u'LOCATION'),
#  (u'America', u'LOCATION'),
#  (u'has', u'O'),
#  (u'teamed', u'O'),
#  (u'up', u'O'),
#  (u'with', u'O'),
#  (u'Uber', u'ORGANIZATION'),
#  (u'to', u'O'),
#  (u'encourage', u'O'),
#  (u'flyers', u'O'),
#  (u'to', u'O'),
#  (u'grab', u'O'),
#  (u'a', u'O'),
#  (u'ride,', u'O'),
#  (u'rather', u'O'),
#  (u'than', u'O'),
#  (u'park', u'O'),
#  (u'at', u'O'),
#  (u'DAL', u'ORGANIZATION'),
#  (u'this', u'O'),
#  (u'fall.', u'O'),
#  (u'Through', u'O'),
#  (u'the', u'O'),
#  (u'partnership,', u'O'),
#  (u'Uber', u'O'),
#  (u'is', u'O'),
#  (u'offering', u'O'),
#  (u'free', u'O'),
#  (u'rides', u'O'),
#  (u'(up', u'O'),
#  (u'to', u'O'),
#  (u'$20)', u'O'),
#  (u'to', u'O'),
#  (u'and', u'O'),
#  (u'from', u'O'),
#  (u'the', u'O'),
#  (u'airport', u'O'),
#  (u'to', u'O'),
#  (u'the', u'O'),
#  (u"airline's", u'O'),
#  (u'new', u'O'),
#  (u'or', u'O'),
#  (u'existing', u'O'),
#  (u'Elevate', u'O'),
#  (u'frequent', u'O'),
#  (u'flyer', u'O'),
#  (u'members', u'O'),
#  (u'with', u'O'),
#  (u'the', u'O'),
#  (u'purchase', u'O'),
#  (u'of', u'O'),
#  (u'any', u'O'),
#  (u'flight', u'O'),
#  (u'originating', u'O'),
#  (u'from', u'O'),
#  (u'DAL', u'ORGANIZATION'),
#  (u'booked', u'O'),
#  (u'through', u'O'),
#  (u'October', u'O'),
#  (u'12,', u'O'),
#  (u'2015,', u'O'),
#  (u'while', u'O'),
#  (u'supplies', u'O'),
#  (u'last.', u'O'),
#  (u'Further,', u'O'),
#  (u'travelers', u'O'),
#  (u'who', u'O'),
#  (u'are', u'O'),
#  (u'new', u'O'),
#  (u'Uber', u'O'),
#  (u'users', u'O'),
#  (u'will', u'O'),
#  (u'also', u'O'),
#  (u'score', u'O'),
#  (u'an', u'O'),
#  (u'additional', u'O'),
#  (u'$20', u'O'),
#  (u'ride*', u'O'),
#  (u'for', u'O'),
#  (u'a', u'O'),
#  (u'future', u'O'),
#  (u'ride.', u'O'),
#  (u'To', u'O'),
#  (u'find', u'O'),
#  (u'out', u'O'),
#  (u'more', u'O'),
#  (u'and', u'O'),
#  (u'view', u'O'),
#  (u'Virgin', u'O'),
#  (u"America's", u'O'),
#  (u'lowest', u'O'),
#  (u'Dallas', u'LOCATION'),
#  (u'Love', u'O'),
#  (u'Field', u'O'),
#  (u'fares,', u'O'),
#  (u'visit:', u'O'),
#  (u'https:www.virginamerica.comcmspromos9-9-15-dal-uber-ride', u'O'),
#  (u'Friday', u'O'),
#  (u'Night', u'O'),
#  (u'Flights:', u'O'),
#  (u'Starting', u'O'),
#  (u'this', u'O'),
#  (u'week,', u'O'),
#  (u'every', u'O'),
#  (u'Thursday', u'O'),
#  (u'afternoon', u'O'),
#  (u'through', u'O'),
#  (u'October', u'O'),
#  (u'8,', u'O'),
#  (u'2015,', u'O'),
#  (u'Uber', u'O'),
#  (u'users', u'O'),
#  (u'can', u'O'),
#  (u'request', u'O'),
#  (u'the', u'O'),
#  (u"'Friday", u'O'),
#  (u'Night', u'O'),
#  (u"Flights'", u'O'),
#  (u'option', u'O'),
#  (u'through', u'O'),
#  (u'the', u'O'),
#  (u'Uber', u'O'),
#  (u'app', u'O'),
#  (u'for', u'O'),
#  (u'a', u'O'),
#  (u'chance', u'O'),
#  (u'to', u'O'),
#  (u'a', u'O'),
#  (u'win', u'O'),
#  (u'a', u'O'),
#  (u'mood-lit', u'O'),
#  (u'flight', u'O'),
#  (u'from', u'O'),
#  (u'DAL', u'ORGANIZATION'),
#  (u'to', u'O'),
#  (u'Washington', u'LOCATION'),
#  (u'D.C.,', u'O'),
#  (u'New', u'O'),
#  (u'York,', u'O'),
#  (u'Los', u'O'),
#  (u'Angeles,', u'O'),
#  (u'San', u'LOCATION'),
#  (u'Francisco', u'LOCATION'),
#  (u'or', u'O'),
#  (u'Austin.', u'O'),
#  (u'The', u'O'),
#  (u"'Friday", u'O'),
#  (u'Night', u'O'),
#  (u"Flights'", u'O'),
#  (u'package', u'O'),
#  (u'for', u'O'),
#  (u'two', u'O'),
#  (u'includes', u'O'),
#  (u'a', u'O'),
#  (u'roundtrip', u'O'),
#  (u'Main', u'O'),
#  (u'Cabin', u'O'),
#  (u'flight', u'O'),
#  (u'on', u'O'),
#  (u'Virgin', u'O'),
#  (u'America,', u'O'),
#  (u'a', u'O'),
#  (u'round', u'O'),
#  (u'trip', u'O'),
#  (u'Uber', u'O'),
#  (u'ride,', u'O'),
#  (u'a', u'O'),
#  (u'two', u'O'),
#  (u'night', u'O'),
#  (u'stay', u'O'),
#  (u'at', u'O'),
#  (u'a', u'O'),
#  (u'four-star', u'O'),
#  (u'property', u'O'),
#  (u'provided', u'O'),
#  (u'by', u'O'),
#  (u'Rocketmiles,', u'O'),
#  (u'and', u'O'),
#  (u'concert', u'O'),
#  (u'tickets', u'O'),
#  (u'provided', u'O'),
#  (u'by', u'O'),
#  (u'ScoreBig', u'O'),
#  (u'to', u'O'),
#  (u'the', u'O'),
#  (u'hottest', u'O'),
#  (u'shows', u'O'),
#  (u'in', u'O'),
#  (u'each', u'O'),
#  (u'DAL', u'O'),
#  (u'destination', u'O'),
#  (u'city', u'O'),
#  (u'-', u'O'),
#  (u'from', u'O'),
#  (u'the', u'O'),
#  (u'Foo', u'O'),
#  (u'Fighters', u'O'),
#  (u'in', u'O'),
#  (u'Los', u'LOCATION'),
#  (u'Angeles,', u'LOCATION'),
#  (u'to', u'O'),
#  (u'Jason', u'PERSON'),
#  (u'Aldean', u'PERSON'),
#  (u'in', u'O'),
#  (u'Washington', u'LOCATION'),
#  (u'D.C.', u'LOCATION'),
#  (u'to', u'O'),
#  (u'an', u'O'),
#  (u'exclusive', u'O'),
#  (u'pass', u'O'),
#  (u'to', u'O'),
#  (u'Austin', u'LOCATION'),
#  (u'City', u'LOCATION'),
#  (u'Limits.', u'O'),
#  (u'How', u'O'),
#  (u'to', u'O'),
#  (u'score', u'O'),
#  (u'a', u'O'),
#  (u"'Friday", u'O'),
#  (u'Night', u'O'),
#  (u"Flights'", u'O'),
#  (u'getaway:', u'O'),
#  (u'--', u'O'),
#  (u'Enter', u'O'),
#  (u'the', u'O'),
#  (u'promo', u'O'),
#  (u'code', u'O'),
#  (u'VXDALFNF', u'O'),
#  (u'into', u'O'),
#  (u'the', u'O'),
#  (u'Uber', u'O'),
#  (u'app.', u'O'),
#  (u'--', u'O'),
#  (u'Each', u'O'),
#  (u'Thursday', u'O'),
#  (u'at', u'O'),
#  (u'3', u'O'),
#  (u'p.m.,', u'O'),
#  (u'open', u'O'),
#  (u'the', u'O'),
#  (u'Uber', u'O'),
#  (u'app', u'O'),
#  (u'and', u'O'),
#  (u'request', u'O'),
#  (u'the', u'O'),
#  (u"'Friday", u'O'),
#  (u'Night', u'O'),
#  (u"Lights'", u'O'),
#  (u'option.', u'O'),
#  (u'--', u'O'),
#  (u'The', u'O'),
#  (u'first', u'O'),
#  (u'users', u'O'),
#  (u'who', u'O'),
#  (u'request', u'O'),
#  (u'will', u'O'),
#  (u'be', u'O'),
#  (u'on', u'O'),
#  (u'their', u'O'),
#  (u'way', u'O'),
#  (u'to', u'O'),
#  (u'the', u'O'),
#  (u'weekend', u'O'),
#  (u'getaway', u'O'),
#  (u'that', u'O'),
#  (u'departs', u'O'),
#  (u'the', u'O'),
#  (u'next', u'O'),
#  (u'day.', u'O'),
#  (u'The', u'O'),
#  (u'winners', u'O'),
#  (u'will', u'O'),
#  (u'be', u'O'),
#  (u'provided', u'O'),
#  (u'with', u'O'),
#  (u'a', u'O'),
#  (u'full', u'O'),
#  (u'itinerary', u'O'),
#  (u'in', u'O'),
#  (u'partnership', u'O'),
#  (u'with', u'O'),
#  (u'Virgin', u'O'),
#  (u'America,', u'O'),
#  (u'Uber,', u'O'),
#  (u'Rocketmiles', u'O'),
#  (u'and', u'O'),
#  (u'ScoreBig.', u'O'),
#  (u'The', u'O'),
#  (u"'Friday", u'O'),
#  (u'Night', u'O'),
#  (u"Lights'", u'O'),
#  (u'entertainment', u'O'),
#  (u'line-up', u'O'),
#  (u'includes:', u'O'),
#  (u'--', u'O'),
#  (u'Weekend', u'O'),
#  (u'1', u'O'),
#  (u'-', u'O'),
#  (u'Washington', u'LOCATION'),
#  (u'DC', u'O'),
#  (u'(Sept', u'O'),
#  (u'11-13)', u'O'),
#  (u'-', u'O'),
#  (u'Jason', u'PERSON'),
#  (u'Aldean', u'PERSON'),
#  (u'(912)', u'O'),
#  (u'--', u'O'),
#  (u'Weekend', u'O'),
#  (u'2', u'O'),
#  (u'-', u'O'),
#  (u'Los', u'LOCATION'),
#  (u'Angeles', u'LOCATION'),
#  (u'(Sept', u'O'),
#  (u'18-20)', u'O'),
#  (u'-', u'O'),
#  (u'Foo', u'O'),
#  (u'Fighters', u'O'),
#  (u'(919)', u'O'),
#  (u'--', u'O'),
#  (u'Weekend', u'O'),
#  (u'3', u'O'),
#  (u'-', u'O'),
#  (u'San', u'LOCATION'),
#  (u'Francisco', u'LOCATION'),
#  (u'(Sept', u'O'),
#  (u'25-27)', u'O'),
#  (u'-', u'O'),
#  (u'ACDC', u'O'),
#  (u'(925)', u'O'),
#  (u'--', u'O'),
#  (u'Weekend', u'O'),
#  (u'4', u'O'),
#  (u'-', u'O'),
#  (u'New', u'LOCATION'),
#  (u'York', u'LOCATION'),
#  (u'City', u'LOCATION'),
#  (u'(Oct', u'O'),
#  (u'2-4)', u'O'),
#  (u'-', u'O'),
#  (u'Zedd', u'O'),
#  (u'(102)', u'O'),
#  (u'--', u'O'),
#  (u'Weekend', u'O'),
#  (u'5', u'O'),
#  (u'-', u'O'),
#  (u'Austin', u'O'),
#  (u'(Oct', u'O'),
#  (u'9-11)', u'O'),
#  (u'-', u'O'),
#  (u'Austin', u'LOCATION'),
#  (u'City', u'LOCATION'),
#  (u'Limits', u'O'),
#  (u'(provided', u'O'),
#  (u'by', u'O'),
#  (u'Uber)', u'LOCATION'),
#  (u'Virgin', u'LOCATION'),
#  (u'America', u'LOCATION'),
#  (u'offers', u'O'),
#  (u'its', u'O'),
#  (u'guests', u'O'),
#  (u'sleek,', u'O'),
#  (u'tech-forward', u'O'),
#  (u'aircraft', u'O'),
#  (u'cabins', u'O'),
#  (u'with', u'O'),
#  (u'custom-designed', u'O'),
#  (u'seating,', u'O'),
#  (u'fleetwide', u'O'),
#  (u'WiFi,', u'O'),
#  (u'signature', u'O'),
#  (u'moodlighting,', u'O'),
#  (u'power', u'O'),
#  (u'outlets', u'O'),
#  (u'near', u'O'),
#  (u'every', u'O'),
#  (u'seat', u'O'),
#  (u'and', u'O'),
#  (u'the', u'O'),
#  (u'unparalleled', u'O'),
#  (u'Red\xae', u'O'),
#  (u'in-flight', u'O'),
#  (u'entertainment', u'O'),
#  (u'system.', u'O'),
#  (u'In', u'O'),
#  (u'addition', u'O'),
#  (u'to', u'O'),
#  (u'a', u'O'),
#  (u'Main', u'O'),
#  (u'Cabin', u'O'),
#  (u'that', u'O'),
#  (u'offers', u'O'),
#  (u'custom-designed', u'O'),
#  (u'leather', u'O'),
#  (u'seating', u'O'),
#  (u'with', u'O'),
#  (u'a', u'O'),
#  (u'deeper,', u'O'),
#  (u'more', u'O'),
#  (u'comfortable', u'O'),
#  (u'pitch,', u'O'),
#  (u'Virgin', u'O'),
#  (u"America's", u'O'),
#  (u'First', u'O'),
#  (u'Class', u'O'),
#  (u'cabin', u'O'),
#  (u'offers', u'O'),
#  (u'plush', u'O'),
#  (u'white', u'O'),
#  (u'leather', u'O'),
#  (u"'cradle", u'O'),
#  (u"sleeper'", u'O'),
#  (u'seating', u'O'),
#  (u'with', u'O'),
#  (u'55', u'O'),
#  (u'inches', u'O'),
#  (u'of', u'O'),
#  (u'pitch,', u'O'),
#  (u'165', u'O'),
#  (u'degrees', u'O'),
#  (u'of', u'O'),
#  (u'recline', u'O'),
#  (u'and', u'O'),
#  (u'lumbar', u'O'),
#  (u'massagers.', u'O'),
#  (u'The', u'O'),
#  (u"carrier's", u'O'),
#  (u'Main', u'O'),
#  (u'Cabin', u'O'),
#  (u'Select', u'O'),
#  (u'service', u'O'),
#  (u'offers', u'O'),
#  (u'38', u'O'),
#  (u'inches', u'O'),
#  (u'of', u'O'),
#  (u'pitch,', u'O'),
#  (u'free', u'O'),
#  (u'food', u'O'),
#  (u'and', u'O'),
#  (u'cocktails,', u'O'),
#  (u'an', u'O'),
#  (u'all-access', u'O'),
#  (u'pass', u'O'),
#  (u'to', u'O'),
#  (u'media', u'O'),
#  (u'content,', u'O'),
#  (u'dedicated', u'O'),
#  (u'overhead', u'O'),
#  (u'bins', u'O'),
#  (u'and', u'O'),
#  (u'priority', u'O'),
#  (u'check-in', u'O'),
#  (u'and', u'O'),
#  (u'boarding.', u'O'),
#  (u'The', u'O'),
#  (u'Red', u'O'),
#  (u'in-flight', u'O'),
#  (u'entertainment', u'O'),
#  (u'platform', u'O'),
#  (u'offers', u'O'),
#  (u'guests', u'O'),
#  (u'their', u'O'),
#  (u'own', u'O'),
#  (u'seatback', u'O'),
#  (u'touch-screen', u'O'),
#  (u'TV,', u'O'),
#  (u'with', u'O'),
#  (u'more', u'O'),
#  (u'25', u'O'),
#  (u'films,', u'O'),
#  (u'live', u'O'),
#  (u'TV,', u'O'),
#  (u'interactive', u'O'),
#  (u'Google', u'ORGANIZATION'),
#  (u'Maps,', u'O'),
#  (u'videogames,', u'O'),
#  (u'a', u'O'),
#  (u'3,000', u'O'),
#  (u'song', u'O'),
#  (u'library', u'O'),
#  (u'and', u'O'),
#  (u'an', u'O'),
#  (u'on-demand', u'O'),
#  (u'menu,', u'O'),
#  (u'which', u'O'),
#  (u'allows', u'O'),
#  (u'flyers', u'O'),
#  (u'to', u'O'),
#  (u'order', u'O'),
#  (u'a', u'O'),
#  (u'cocktail', u'O'),
#  (u'or', u'O'),
#  (u'snack', u'O'),
#  (u'from', u'O'),
#  (u'their', u'O'),
#  (u'seatback', u'O'),
#  (u'any', u'O'),
#  (u'time', u'O'),
#  (u'during', u'O'),
#  (u'a', u'O'),
#  (u'flight.', u'O'),
#  (u'Virgin', u'LOCATION'),
#  (u'America', u'LOCATION'),
#  (u'also', u'O'),
#  (u'offers', u'O'),
#  (u'DAL', u'O'),
#  (u'travelers', u'O'),
#  (u'a', u'O'),
#  (u'check-in', u'O'),
#  (u'lounge', u'O'),
#  (u'that', u'O'),
#  (u'mirrors', u'O'),
#  (u'the', u'O'),
#  (u'sleek', u'O'),
#  (u'look', u'O'),
#  (u'and', u'O'),
#  (u'feel', u'O'),
#  (u'of', u'O'),
#  (u'the', u'O'),
#  (u"carrier's", u'O'),
#  (u'aircraft', u'O'),
#  (u'cabins', u'O'),
#  (u'and', u'O'),
#  (u'is', u'O'),
#  (u'the', u'O'),
#  (u'only', u'O'),
#  (u'dedicated', u'O'),
#  (u'VIP', u'O'),
#  (u'check-in', u'O'),
#  (u'area', u'O'),
#  (u'of', u'O'),
#  (u'its', u'O'),
#  (u'kind', u'O'),
#  (u'at', u'O'),
#  (u'Love', u'O'),
#  (u'Field.', u'O'),
#  (u'The', u'O'),
#  (u'check-in', u'O'),
#  (u'lounge', u'O'),
#  (u'offers', u'O'),
#  (u'First', u'O'),
#  (u'Class', u'O'),
#  (u'guests', u'O'),
#  (u'and', u'O'),
#  (u'Elevate', u'O'),
#  (u'Gold', u'O'),
#  (u'members', u'O'),
#  (u'an', u'O'),
#  (u'upgraded', u'O'),
#  (u'experience', u'O'),
#  (u'from', u'O'),
#  (u'the', u'O'),
#  (u'moment', u'O'),
#  (u'they', u'O'),
#  (u'arrive', u'O'),
#  (u'at', u'O'),
#  (u'the', u'O'),
#  (u"airport's", u'O'),
#  (u'convenient', u'O'),
#  (u'downtown', u'O'),
#  (u'location', u'O'),
#  (u'-', u'O'),
#  (u'complete', u'O'),
#  (u'with', u'O'),
#  (u'a', u'O'),
#  (u'dedicated', u'O'),
#  (u'Virgin', u'LOCATION'),
#  (u'America', u'LOCATION'),
#  (u'VIP', u'O'),
#  (u'concierge', u'O'),
#  (u'to', u'O'),
#  (u'assist', u'O'),
#  (u'with', u'O'),
#  (u'their', u'O'),
#  (u'travel', u'O'),
#  (u'needs.', u'O'),
#  (u'Virgin', u'LOCATION'),
#  (u'America', u'LOCATION'),
#  (u'launched', u'O'),
#  (u'its', u'O'),
#  (u'service', u'O'),
#  (u'at', u'O'),
#  (u'the', u'O'),
#  (u'new', u'O'),
#  (u'Dallas', u'LOCATION'),
#  (u'Love', u'LOCATION'),
#  (u'Field', u'LOCATION'),
#  (u'airport', u'O'),
#  (u'in', u'O'),
#  (u'October', u'O'),
#  (u'last', u'O'),
#  (u'year', u'O'),
#  (u'with', u'O'),
#  (u'a', u'O'),
#  (u'"Downtown', u'O'),
#  (u'Express"', u'O'),
#  (u'flight', u'O'),
#  (u'-', u'O'),
#  (u'marking', u'O'),
#  (u'the', u'O'),
#  (u'last', u'O'),
#  (u'service', u'O'),
#  (u'from', u'O'),
#  (u'DFW', u'ORGANIZATION'),
#  (u'and', u'O'),
#  (u'the', u'O'),
#  (u'first', u'O'),
#  (u'to', u'O'),
#  (u'touch', u'O'),
#  (u'down', u'O'),
#  (u'at', u'O'),
#  (u'DAL.', u'O'),
#  (u'The', u'O'),
#  (u'airline', u'O'),
#  (u'teamed', u'O'),
#  (u'up', u'O'),
#  (u'with', u'O'),
#  (u'Uber', u'ORGANIZATION'),
#  (u'at', u'O'),
#  (u'launch', u'O'),
#  (u'to', u'O'),
#  (u'offer', u'O'),
#  (u'guests', u'O'),
#  (u'free', u'O'),
#  (u'Uber', u'O'),
#  (u'rides', u'O'),
#  (u'with', u'O'),
#  (u'ticket', u'O'),
#  (u'purchase', u'O'),
#  (u'and', u'O'),
#  (u'a', u'O'),
#  (u'surprise,', u'O'),
#  (u'on-demand', u'O'),
#  (u'flight', u'O'),
#  (u'pick-up', u'O'),
#  (u'via', u'O'),
#  (u'the', u'O'),
#  (u'Uber', u'O'),
#  (u'app', u'O'),
#  (u'to', u'O'),
#  (u'beat', u'O'),
#  (u'the', u'O'),
#  (u'cross-town', u'O'),
#  (u'traffic', u'O'),
#  (u'between', u'O'),
#  (u'DFW', u'LOCATION'),
#  (u'and', u'O'),
#  (u'DAL.', u'O'),
#  (u'In', u'O'),
#  (u'true', u'O'),
#  (u'Virgin', u'O'),
#  (u'fashion,', u'O'),
#  (u'the', u'O'),
#  (u'"Downtown', u'O'),
#  (u'Express"', u'O'),
#  (u'flight', u'O'),
#  (u'was', u'O'),
#  (u'a', u'O'),
#  (u'party', u'O'),
#  (u'with', u'O'),
#  (u'a', u'O'),
#  (u'performance', u'O'),
#  (u'in-flight', u'O'),
#  (u'by', u'O'),
#  (u'Grammy-award', u'O'),
#  (u'winning', u'O'),
#  (u'country', u'O'),
#  (u'star,', u'O'),
#  (u'Kacey', u'O'),
#  (u'Musgraves.', u'O'),
#  (u'Since', u'O'),
#  (u'its', u'O'),
#  (u'2007', u'O'),
#  (u'launch,', u'O'),
#  (u'Virgin', u'LOCATION'),
#  (u'America', u'LOCATION'),
#  (u'has', u'O'),
#  (u'created', u'O'),
#  (u'more', u'O'),
#  (u'than', u'O'),
#  (u'2,800', u'O'),
#  (u'new', u'O'),
#  (u'jobs', u'O'),
#  (u'and', u'O'),
#  (u'expanded', u'O'),
#  (u'its', u'O'),
#  (u'network', u'O'),
#  (u'to', u'O'),
#  (u'include', u'O'),
#  (u'Austin,', u'O'),
#  (u'Boston,', u'O'),
#  (u'Cancun,', u'O'),
#  (u'Chicago,', u'O'),
#  (u'Dallas', u'LOCATION'),
#  (u'Love', u'O'),
#  (u'Field,', u'O'),
#  (u'Fort', u'O'),
#  (u'Lauderdale,', u'O'),
#  (u'Las', u'O'),
#  (u'Vegas,', u'O'),
#  (u'Los', u'O'),
#  (u'Angeles,', u'O'),
#  (u'Los', u'O'),
#  (u'Cabos,', u'O'),
#  (u'Newark,', u'O'),
#  (u'New', u'LOCATION'),
#  (u'York', u'LOCATION'),
#  (u'(JFK),', u'LOCATION'),
#  (u'LaGuardia', u'LOCATION'),
#  (u'Airport', u'LOCATION'),
#  (u'(LGA),', u'O'),
#  (u'Orlando,', u'O'),
#  (u'Palm', u'LOCATION'),
#  (u'Springs', u'LOCATION'),
#  (u'(seasonal),', u'O'),
#  (u'Portland,', u'O'),
#  (u'Puerto', u'O'),
#  (u'Vallarta,', u'O'),
#  (u'San', u'O'),
#  (u'Diego,', u'O'),
#  (u'San', u'O'),
#  (u'Francisco,', u'O'),
#  (u'Seattle,', u'O'),
#  (u'Washington', u'LOCATION'),
#  (u'D.C.', u'LOCATION'),
#  (u'(IAD', u'O'),
#  (u'and', u'O'),
#  (u'DCA),', u'O'),
#  (u'Honolulu', u'LOCATION'),
#  (u'(as', u'O'),
#  (u'of', u'O'),
#  (u'November', u'O'),
#  (u'2,', u'O'),
#  (u'2015)', u'O'),
#  (u'and', u'O'),
#  (u'Kahului,', u'O'),
#  (u'Maui', u'LOCATION'),
#  (u'(as', u'O'),
#  (u'of', u'O'),
#  (u'December', u'O'),
#  (u'3,', u'O'),
#  (u'2015).', u'O'),
#  (u'Photos', u'O'),
#  (u'of', u'O'),
#  (u'Virgin', u'O'),
#  (u"America's", u'O'),
#  (u'unique', u'O'),
#  ...]
